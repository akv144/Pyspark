# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2995350661662673#setting/sparkui/0625-190351-pvre4h6/driver-6839242884440573669">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2995350661662673#setting/sparkui/0625-190351-pvre4h6/driver-6839242884440573669">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spd=spark.read.option("delimiter", "\t").option("header",True).csv("/FileStore/tables/day1.txt")

# %%
display(spd)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
av=spd.filter(spd.POC=="Abhishek").orderBy(spd.Email).drop(spd["EMP_NAME"])

# %%
spd.columns
# Out:
# Out[6]: ['FORTNIGHT',
#  'Period Ending',
#  'EMP_ID',
#  'EMP_NAME',
#  'DG',
#  'DU',
#  'CLIENT_NAME',
#  'PROJECT',
#  'DOJ',
#  'LEVEL',
#  'PROJ_ST_DT',
#  'Email',
#  'LEVEL_MAPPING',
#  'WBSExter',
#  'WBSE_Description',
#  'PDR Hours',
#  'Pending hours',
#  'Reversals',
#  'POC',
#  'Status',
#  'Comments']

# %%
spd.select(spd.FORTNIGHT,spd["Period Ending"],spd.Email,spd.LEVEL,).filter((spd.POC=="Abhishek") & (spd.WBSE_Description=="Central Training - Participant")).orderBy(spd.Email).show()
# Out:
# +---------+-------------+-------------------+-----+
# |FORTNIGHT|Period Ending|              Email|LEVEL|
# +---------+-------------+-------------------+-----+
# |31-Oct-21|    31-Oct-21|     harsh.deshmukh|   12|
# |15-Oct-21|    15-Oct-21|       jyothi.reddi|   10|
# |31-Oct-21|    31-Oct-21|       jyothi.reddi|   10|
# |30-Sep-21|    30-Sep-21|       jyothi.reddi|   10|
# |30-Sep-21|    30-Sep-21|       jyothi.reddi|   10|
# |15-Oct-21|    15-Oct-21|priya.devidas.pawar|   10|
# |30-Sep-21|    30-Sep-21|    ritika.kandhari|   11|
# |15-Oct-21|    15-Oct-21|        ritu.d.jain|    9|
# |31-Oct-21|    31-Oct-21|rohit.prakash.singh|   11|
# |15-Oct-21|    30-Sep-21| sai.krishna.vemula|   10|
# |31-Oct-21|    31-Oct-21|   sowmya.mangineni|   11|
# |15-Oct-21|    15-Oct-21|   sowmya.mangineni|   11|
# |15-Oct-21|    15-Oct-21|   sowmya.mangineni|   11|
# |15-Oct-21|    15-Oct-21|      tanmoy.biswas|   11|
# |31-Oct-21|    31-Oct-21|      tanmoy.biswas|   11|
# ...

# %%
av.toPandas()6
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>FORTNIGHT</th>
#       <th>Period Ending</th>
#       <th>EMP_ID</th>
#       <th>DG</th>
#       <th>DU</th>
#       <th>CLIENT_NAME</th>
#       <th>PROJECT</th>
#       <th>DOJ</th>
#       <th>LEVEL</th>
#       <th>PROJ_ST_DT</th>
#       <th>Email</th>
#       <th>LEVEL_MAPPING</th>
#       <th>WBSExter</th>
#       <th>WBSE_Description</th>
#       <th>PDR Hours</th>
#       <th>Pending hours</th>
#       <th>Reversals</th>
#       <th>POC</th>
#       <th>Status</th>
#       <th>Comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31-Oct-21</td>
# ...

# %%
av.groupBy().toPandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1379483064943877> in <module>
# ----> 1 av.groupBy().toPandas()
#
# AttributeError: 'GroupedData' object has no attribute 'toPandas'

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-154029079861830> in <module>
# ----> 1 df.show()
#
# NameError: name 'df' is not defined

# %%
print("hello)
# Out:
#   File "<command-154029079861831>", line 1
#     print("hello)
#                  ^
# SyntaxError: EOL while scanning string literal

# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2995350661662673#setting/sparkui/0625-190351-pvre4h6/driver-6839242884440573669">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2995350661662673#setting/sparkui/0625-190351-pvre4h6/driver-6839242884440573669">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
print("hello")

# %%
print("hello")

# %%
print("hello")
# Out:
# hello

# %%
l=[[1,2],[3,4]]
df=spark.createDataFrame(l,["1st","2nd"])

# %%
df.show()
# Out:
# +---+---+
# |1st|2nd|
# +---+---+
# |  1|  2|
# |  3|  4|
# +---+---+
